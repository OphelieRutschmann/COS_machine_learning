# %%
import pandas as pd
from sklearn.datasets import fetch_openml

# Download the data and extract the feature matrix X
dataset = fetch_openml(data_id=42803, as_frame=True)
df_X = dataset["frame"]
print('Dataset shape before cleaning:', df_X.shape)

# Change datatype of features where needed
df_X["Sex_of_Driver"] = df_X["Sex_of_Driver"].astype("float")

# Combine features and create new ones where needed
df_X["Timestamp"] = pd.to_datetime(df_X["Date"] + " " + df_X["Time"])
df_X = df_X.drop(labels=["Date", "Time"], axis=1)
df_X["day_of_week"] = df_X["Timestamp"].dt.day_of_week
df_X["hour_of_day"] = df_X["Timestamp"].dt.hour

# Drop duplicates based on 'columns_to_consider'
columns_to_consider = df_X.drop(labels=["Accident_Index"], axis=1).columns
df_X = df_X.drop_duplicates(subset=columns_to_consider)

# Drop missing values based on feature and sample axis
df_X = df_X.dropna(thresh=df_X.shape[1] * 0.75, axis=0)
df_X = df_X.dropna(thresh=df_X.shape[0] * 0.85, axis=1)

# Rest the index numbering
df_X = df_X.reset_index(drop=True)

# Dropping some entries according to some feature criteria
entries_to_drop = df_X["Number_of_Vehicles"].gt(30)
df_X = df_X[~entries_to_drop]

# Remove entries of the 10 most frequent accidents
df_non_numerical = df_X.select_dtypes(exclude=["number", "datetime"])
accident_ids = df_non_numerical["Accident_Index"].value_counts().head(10).index
df_X = df_X[~df_X["Accident_Index"].isin(accident_ids)]
print('Dataset shape after cleaning:', df_X.shape)
# Out:
# Dataset shape before cleaning: (363243, 67)
# Dataset shape after cleaning: (317659, 61)

# %%
import matplotlib.pyplot as plt

df_X.hist(bins=25, figsize=(15,30), layout = (-1, 4), edgecolor="black")
plt.tight_layout()
# Out:
# /home/ruop/.local/share/mamba/envs/adsml/lib/python3.9/site-packages/pandas/plotting/_core.py:1746: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
df_X[["Towing_and_Articulation", "Was_Vehicle_Left_Hand_Drive?"]].mode()
# Out:
#    Towing_and_Articulation  Was_Vehicle_Left_Hand_Drive?
# 0                      0.0                           1.0

# %%
# Collects for each feature the most frequent entry
most_frequent_entry = df_X.mode()

# Checks for each entry if it contains the most frequent entry
df_freq = df_X.eq(most_frequent_entry.values, axis=1)

# Computes the mean of the 'is_most_frequent' occurrence
df_freq = df_freq.mean().sort_values(ascending=False)

# Show the 5 top features with the highest ratio of singular value content
df_freq.head()
# Out:
# Pedestrian_Crossing-Human_Control    0.995155
# Was_Vehicle_Left_Hand_Drive?         0.990336
# Carriageway_Hazards                  0.983548
# Towing_and_Articulation              0.983073
# Vehicle_Location-Restricted_Lane     0.981943
# dtype: float64

# %%
df_freq.plot.bar(figsize=(15, 4));

# %%
# Shape of feature matrix before cleaning
print("Shape before cleaning:", df_X.shape)

# Loop through the indices where 'most_frequent_ratio' is great than 99%
for col in df_freq[df_freq > 0.99].index:

    # Only keep entries that correspond to the majority value
    df_X = df_X[df_X[col].isin(most_frequent_entry[col])]

    #  Remove feature
    df_X = df_X.drop(columns=col)

# Shape of feature matrix after cleaning
print("Shape after cleaning:", df_X.shape)
# Out:
# Shape before cleaning: (317659, 61)
# Shape after cleaning: (313061, 59)

# %%
# Show histogram of two particular features
df_X[["Age_of_Driver", "hour_of_day"]].hist(
    bins=24, figsize=(15, 3), layout=(-1, 2), edgecolor="black");

# %%
# Remove driver younger than 16 years of age
df_X = df_X[~df_X["Age_of_Driver"].lt(16)]
df_X.shape
# Out:
# (311175, 59)

# %%
import numpy as np
# Establish new feature name and value boundaries
new_features = {
    "night": [0, 6],
    "morning": [6, 11],
    "lunch": [11, 14],
    "afternoon": [14, 19],
    "evening": [19, 24],
}

# Loop through new features and add them to the feature matrix
for key, value in new_features.items():
    df_X[key] = np.logical_and(
        df_X["hour_of_day"] >= value[0], df_X["hour_of_day"] < value[1]
    ).astype("int")

df_X.shape
# Out:
# (311175, 64)

# %%
# Show the top few missing values
df_X.isna().sum().sort_values(ascending=False).head(5)
# Out:
# Casualty_Home_Area_Type      35334
# Age_of_Driver                31428
# Age_Band_of_Driver           31428
# LSOA_of_Accident_Location    20419
# Age_of_Casualty               4962
# dtype: int64

# %%
df_X[["Casualty_Home_Area_Type", "Age_of_Driver",
      "Age_Band_of_Driver", "LSOA_of_Accident_Location"]].hist(
    layout=(-1, 4), figsize=(15, 3));

# %%
# Select non-numerical columns
non_numb_col = df_X.select_dtypes(include="object").columns

# Fill up missing values in non-numerical columns
df_X[non_numb_col] = df_X[non_numb_col].fillna("None")

# Check for remaining missing values
df_X[non_numb_col].isna().sum()
# Out:
# Accident_Index               0
# Local_Authority_(Highway)    0
# LSOA_of_Accident_Location    0
# dtype: int64

# %%
[df_X.isna().sum() != 0]
# Out:
# [Accident_Index              False
#  Vehicle_Reference_df_res    False
#  Vehicle_Type                 True
#  Towing_and_Articulation      True
#  Vehicle_Manoeuvre            True
#                              ...
#  night                       False
#  morning                     False
#  lunch                       False
#  afternoon                   False
#  evening                     False
#  Length: 64, dtype: bool]

# %%
# Extract columns to fill up
cols = df_X.columns[df_X.isna().sum() != 0]

# %%
# Loop through each column and fill up with missing values
cols_median = df_X[cols].nunique() >= 25

# Fill discrete entries with most frequent entry
df_X[cols[~cols_median]] = df_X[cols[~cols_median]].fillna(
    df_X[cols[~cols_median]].mode().T[0])


# Fill continuous features with median value
df_X[cols[cols_median]] = df_X[cols[cols_median]].fillna(
    df_X[cols[cols_median]].median(numeric_only=True))

# %%
# Show the top few missing values
df_X.isna().sum().sort_values(ascending=False).head(5)
# Out:
# Timestamp               43
# Accident_Index           0
# Age_Band_of_Casualty     0
# Light_Conditions         0
# Weather_Conditions       0
# dtype: int64

# %%
df_X["Timestamp"] = df_X["Timestamp"].fillna(method="ffill").fillna(method="bfill")

# %%
df_X[["Location_Northing_OSGR", "1st_Road_Number",
      "Journey_Purpose_of_Driver", "Pedestrian_Crossing-Physical_Facilities"]].plot(
    lw=0, marker=".", subplots=True, layout=(-1, 2), markersize=0.1, figsize=(15, 6));

# %%
# Creates mask to identify numerical features with more or less than 25 unique features
cols_continuous = df_X.select_dtypes(include="number").nunique() >= 25

# %%
df_X.select_dtypes(include="number").nunique() >= 25
# Out:
# Vehicle_Reference_df_res                       False
# Vehicle_Type                                   False
# Towing_and_Articulation                        False
# Vehicle_Manoeuvre                              False
# Vehicle_Location-Restricted_Lane               False
# Junction_Location                              False
# Skidding_and_Overturning                       False
# Hit_Object_in_Carriageway                      False
# Vehicle_Leaving_Carriageway                    False
# Hit_Object_off_Carriageway                     False
# 1st_Point_of_Impact                            False
# Journey_Purpose_of_Driver                      False
# Sex_of_Driver                                  False
# Age_of_Driver                                   True
# Age_Band_of_Driver                             False
# Location_Easting_OSGR                           True
# Location_Northing_OSGR                          True
# Longitude                                       True
# Latitude                                        True
# Police_Force                                    True
# Accident_Severity                              False
# Number_of_Vehicles                             False
# Number_of_Casualties                           False
# Day_of_Week                                    False
# Local_Authority_(District)                      True
# 1st_Road_Class                                 False
# 1st_Road_Number                                 True
# Road_Type                                      False
# Speed_limit                                    False
# Junction_Detail                                False
# 2nd_Road_Number                                 True
# Pedestrian_Crossing-Physical_Facilities        False
# Light_Conditions                               False
# Weather_Conditions                             False
# Road_Surface_Conditions                        False
# Special_Conditions_at_Site                     False
# Carriageway_Hazards                            False
# Urban_or_Rural_Area                            False
# Did_Police_Officer_Attend_Scene_of_Accident    False
# Vehicle_Reference_df                           False
# Casualty_Reference                              True
# Casualty_Class                                 False
# Sex_of_Casualty                                False
# Age_of_Casualty                                 True
# Age_Band_of_Casualty                           False
# Casualty_Severity                              False
# Pedestrian_Location                            False
# Pedestrian_Movement                            False
# Car_Passenger                                  False
# Bus_or_Coach_Passenger                         False
# Pedestrian_Road_Maintenance_Worker             False
# Casualty_Type                                  False
# Casualty_Home_Area_Type                        False
# day_of_week                                    False
# hour_of_day                                    False
# night                                          False
# morning                                        False
# lunch                                          False
# afternoon                                      False
# evening                                        False
# dtype: bool

# %%
# Create a new dataframe which only contains the continuous features
df_continuous = df_X[(cols_continuous == True).index]
df_continuous.shape
# Out:
# (311175, 60)

# %%
# Create a new dataframe which doesn't contain the numerical continuous features
df_discrete = df_X[cols_continuous[~cols_continuous].index]
df_discrete.shape
# Out:
# (311175, 49)

# %%
# Establish number of columns and rows needed to plot all features
n_cols = 5
n_elements = len(df_discrete.columns)
n_rows = np.ceil(n_elements / n_cols).astype("int")
print(n_cols, n_rows)
# Out:
# 5 10

# %%
# Specify y_value (ideally a continuous feature)
y_value = df_X["Age_of_Driver"]

# %%
# Specify features of interest
selected_features = ["Vehicle_Reference_df_res", "Towing_and_Articulation",
                     "Skidding_and_Overturning", "Bus_or_Coach_Passenger",
                     "Pedestrian_Road_Maintenance_Worker", "night"]

# %%
import seaborn as sns
# Create a figure with 3 x 2 subplots
fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(16, 8))

# Loop through these features and plot entries from each feature against `Latitude`
for col, ax in zip(selected_features, axes.ravel()):
    sns.stripplot(data=df_X, x=col, y=df_X["Latitude"], ax=ax, palette="tab10", size=2, alpha=0.5)
plt.tight_layout()

# %%
df_corr = df_X.corr(method="pearson")
df_corr.round(3)
# Out:
#                                              Vehicle_Reference_df_res  \
# Vehicle_Reference_df_res                                        1.000
# Vehicle_Type                                                    0.013
# Towing_and_Articulation                                         0.005
# Vehicle_Manoeuvre                                              -0.128
# Vehicle_Location-Restricted_Lane                               -0.013
# Junction_Location                                              -0.078
# Skidding_and_Overturning                                       -0.105
# Hit_Object_in_Carriageway                                      -0.074
# Vehicle_Leaving_Carriageway                                    -0.106
# Hit_Object_off_Carriageway                                     -0.110
# 1st_Point_of_Impact                                             0.021
# Journey_Purpose_of_Driver                                       0.004
# Sex_of_Driver                                                   0.053
# Age_of_Driver                                                   0.034
# Age_Band_of_Driver                                              0.034
# Location_Easting_OSGR                                          -0.020
# Location_Northing_OSGR                                          0.008
# Longitude                                                      -0.020
# Latitude                                                        0.008
# Police_Force                                                    0.015
# Accident_Severity                                              -0.015
# Number_of_Vehicles                                              0.585
# Number_of_Casualties                                            0.184
# Day_of_Week                                                     0.007
# Local_Authority_(District)                                      0.019
# 1st_Road_Class                                                 -0.125
# 1st_Road_Number                                                -0.023
# Road_Type                                                      -0.060
# Speed_limit                                                     0.128
# Junction_Detail                                                -0.037
# 2nd_Road_Number                                                -0.020
# Pedestrian_Crossing-Physical_Facilities                        -0.042
# Light_Conditions                                               -0.023
# Weather_Conditions                                             -0.014
# Road_Surface_Conditions                                        -0.008
# Special_Conditions_at_Site                                      0.011
# Carriageway_Hazards                                             0.006
# Urban_or_Rural_Area                                             0.072
# Did_Police_Officer_Attend_Scene_of_Accident                    -0.073
# Vehicle_Reference_df                                            0.295
# Casualty_Reference                                              0.140
# Casualty_Class                                                 -0.135
# Sex_of_Casualty                                                 0.016
# Age_of_Casualty                                                 0.025
# Age_Band_of_Casualty                                            0.032
# Casualty_Severity                                               0.027
# Pedestrian_Location                                            -0.164
# Pedestrian_Movement                                            -0.135
# Car_Passenger                                                   0.044
# Bus_or_Coach_Passenger                                         -0.034
# Pedestrian_Road_Maintenance_Worker                             -0.101
# Casualty_Type                                                   0.097
# Casualty_Home_Area_Type                                         0.010
# day_of_week                                                    -0.003
# hour_of_day                                                    -0.002
# night                                                          -0.031
# morning                                                         0.008
# lunch                                                           0.010
# afternoon                                                       0.023
# evening                                                        -0.032
#
#                                              Vehicle_Type  \
# Vehicle_Reference_df_res                            0.013
# Vehicle_Type                                        1.000
# Towing_and_Articulation                             0.126
# Vehicle_Manoeuvre                                  -0.043
# Vehicle_Location-Restricted_Lane                    0.008
# Junction_Location                                  -0.061
# Skidding_and_Overturning                            0.007
# Hit_Object_in_Carriageway                          -0.016
# Vehicle_Leaving_Carriageway                         0.003
# Hit_Object_off_Carriageway                          0.003
# 1st_Point_of_Impact                                -0.010
# Journey_Purpose_of_Driver                          -0.161
# Sex_of_Driver                                      -0.005
# Age_of_Driver                                       0.049
# Age_Band_of_Driver                                  0.044
# Location_Easting_OSGR                              -0.028
# Location_Northing_OSGR                              0.032
# Longitude                                          -0.028
# Latitude                                            0.032
# Police_Force                                        0.029
# Accident_Severity                                  -0.013
# Number_of_Vehicles                                  0.044
# Number_of_Casualties                                0.037
# Day_of_Week                                        -0.000
# Local_Authority_(District)                          0.031
# 1st_Road_Class                                     -0.038
# 1st_Road_Number                                    -0.009
# Road_Type                                          -0.021
# Speed_limit                                         0.079
# Junction_Detail                                    -0.030
# 2nd_Road_Number                                    -0.012
# Pedestrian_Crossing-Physical_Facilities            -0.024
# Light_Conditions                                   -0.006
# Weather_Conditions                                  0.010
# Road_Surface_Conditions                             0.016
# Special_Conditions_at_Site                          0.015
# Carriageway_Hazards                                 0.004
# Urban_or_Rural_Area                                 0.071
# Did_Police_Officer_Attend_Scene_of_Accident        -0.004
# Vehicle_Reference_df                                0.009
# Casualty_Reference                                  0.028
# Casualty_Class                                      0.042
# Sex_of_Casualty                                     0.018
# Age_of_Casualty                                     0.033
# Age_Band_of_Casualty                                0.030
# Casualty_Severity                                  -0.001
# Pedestrian_Location                                 0.026
# Pedestrian_Movement                                 0.033
# Car_Passenger                                       0.012
# Bus_or_Coach_Passenger                              0.022
# Pedestrian_Road_Maintenance_Worker                 -0.002
# Casualty_Type                                       0.423
# Casualty_Home_Area_Type                             0.029
# day_of_week                                        -0.012
# hour_of_day                                        -0.035
# night                                               0.007
# morning                                             0.018
# lunch                                               0.022
# afternoon                                          -0.012
# evening                                            -0.030
#
#                                              Towing_and_Articulation  \
# Vehicle_Reference_df_res                                       0.005
# Vehicle_Type                                                   0.126
# Towing_and_Articulation                                        1.000
# Vehicle_Manoeuvre                                              0.015
# Vehicle_Location-Restricted_Lane                               0.000
# Junction_Location                                             -0.031
# Skidding_and_Overturning                                       0.036
# Hit_Object_in_Carriageway                                     -0.002
# Vehicle_Leaving_Carriageway                                    0.002
# Hit_Object_off_Carriageway                                     0.002
# 1st_Point_of_Impact                                            0.010
# Journey_Purpose_of_Driver                                     -0.103
# Sex_of_Driver                                                 -0.035
# Age_of_Driver                                                  0.031
# Age_Band_of_Driver                                             0.031
# Location_Easting_OSGR                                         -0.021
# Location_Northing_OSGR                                         0.017
# Longitude                                                     -0.021
# Latitude                                                       0.017
# Police_Force                                                   0.022
# Accident_Severity                                             -0.032
# Number_of_Vehicles                                             0.022
# Number_of_Casualties                                           0.003
# Day_of_Week                                                   -0.001
# Local_Authority_(District)                                     0.024
# 1st_Road_Class                                                -0.047
# 1st_Road_Number                                               -0.013
# Road_Type                                                     -0.023
# Speed_limit                                                    0.088
# Junction_Detail                                               -0.028
# 2nd_Road_Number                                               -0.015
# Pedestrian_Crossing-Physical_Facilities                       -0.027
# Light_Conditions                                              -0.005
# Weather_Conditions                                             0.000
# Road_Surface_Conditions                                       -0.003
# Special_Conditions_at_Site                                     0.019
# Carriageway_Hazards                                            0.003
# Urban_or_Rural_Area                                            0.075
# Did_Police_Officer_Attend_Scene_of_Accident                   -0.008
# Vehicle_Reference_df                                           0.011
# Casualty_Reference                                             0.002
# Casualty_Class                                                -0.008
# Sex_of_Casualty                                               -0.011
# Age_of_Casualty                                                0.022
# Age_Band_of_Casualty                                           0.021
# Casualty_Severity                                             -0.022
# Pedestrian_Location                                           -0.005
# Pedestrian_Movement                                           -0.003
# Car_Passenger                                                 -0.004
# Bus_or_Coach_Passenger                                        -0.004
# Pedestrian_Road_Maintenance_Worker                            -0.011
# Casualty_Type                                                  0.057
# Casualty_Home_Area_Type                                        0.035
# day_of_week                                                   -0.010
# hour_of_day                                                   -0.020
# night                                                          0.005
# morning                                                        0.010
# lunch                                                          0.015
# afternoon                                                     -0.011
# evening                                                       -0.015
#
#                                              Vehicle_Manoeuvre  \
# Vehicle_Reference_df_res                                -0.128
# Vehicle_Type                                            -0.043
# Towing_and_Articulation                                  0.015
# Vehicle_Manoeuvre                                        1.000
# Vehicle_Location-Restricted_Lane                        -0.050
# Junction_Location                                        0.038
# Skidding_and_Overturning                                 0.141
# Hit_Object_in_Carriageway                                0.082
# Vehicle_Leaving_Carriageway                              0.128
# Hit_Object_off_Carriageway                               0.132
# 1st_Point_of_Impact                                     -0.104
# Journey_Purpose_of_Driver                                0.009
# Sex_of_Driver                                           -0.090
# Age_of_Driver                                           -0.040
# Age_Band_of_Driver                                      -0.036
# Location_Easting_OSGR                                   -0.040
# Location_Northing_OSGR                                   0.028
# Longitude                                               -0.040
# Latitude                                                 0.028
# Police_Force                                             0.035
# Accident_Severity                                       -0.102
# Number_of_Vehicles                                      -0.154
# Number_of_Casualties                                     0.011
# Day_of_Week                                             -0.012
# Local_Authority_(District)                               0.038
# 1st_Road_Class                                           0.003
# 1st_Road_Number                                          0.011
# Road_Type                                                0.015
# Speed_limit                                              0.086
# Junction_Detail                                         -0.035
# 2nd_Road_Number                                         -0.015
# Pedestrian_Crossing-Physical_Facilities                 -0.034
# Light_Conditions                                         0.065
# Weather_Conditions                                       0.011
# Road_Surface_Conditions                                  0.045
# Special_Conditions_at_Site                               0.007
# Carriageway_Hazards                                      0.018
# Urban_or_Rural_Area                                      0.096
# Did_Police_Officer_Attend_Scene_of_Accident             -0.054
# Vehicle_Reference_df                                    -0.057
# Casualty_Reference                                       0.006
# Casualty_Class                                           0.002
# Sex_of_Casualty                                         -0.046
# Age_of_Casualty                                         -0.029
# Age_Band_of_Casualty                                    -0.030
# Casualty_Severity                                       -0.085
# Pedestrian_Location                                     -0.005
# Pedestrian_Movement                                     -0.018
# Car_Passenger                                           -0.011
# Bus_or_Coach_Passenger                                  -0.023
# Pedestrian_Road_Maintenance_Worker                       0.026
# Casualty_Type                                           -0.014
# Casualty_Home_Area_Type                                  0.042
# day_of_week                                              0.014
# hour_of_day                                             -0.006
# night                                                    0.047
# morning                                                 -0.000
# lunch                                                   -0.032
# afternoon                                               -0.025
# evening                                                  0.038
#
#                                              Vehicle_Location-Restricted_Lane  \
# Vehicle_Reference_df_res                                               -0.013
# Vehicle_Type                                                            0.008
# Towing_and_Articulation                                                 0.000
# Vehicle_Manoeuvre                                                      -0.050
# Vehicle_Location-Restricted_Lane                                        1.000
# Junction_Location                                                      -0.014
# Skidding_and_Overturning                                               -0.007
# Hit_Object_in_Carriageway                                               0.040
# Vehicle_Leaving_Carriageway                                             0.015
# Hit_Object_off_Carriageway                                              0.013
# 1st_Point_of_Impact                                                     0.004
# Journey_Purpose_of_Driver                                               0.001
# Sex_of_Driver                                                           0.017
# Age_of_Driver                                                           0.008
# Age_Band_of_Driver                                                      0.001
# Location_Easting_OSGR                                                   0.000
# Location_Northing_OSGR                                                  0.009
# Longitude                                                               0.000
# Latitude                                                                0.009
# Police_Force                                                            0.013
# Accident_Severity                                                      -0.011
# Number_of_Vehicles                                                     -0.038
# Number_of_Casualties                                                   -0.038
# Day_of_Week                                                            -0.000
# Local_Authority_(District)                                              0.013
# 1st_Road_Class                                                          0.030
# 1st_Road_Number                                                         0.004
# Road_Type                                                               0.028
# Speed_limit                                                            -0.040
# Junction_Detail                                                         0.020
# 2nd_Road_Number                                                        -0.016
# Pedestrian_Crossing-Physical_Facilities                                -0.006
# Light_Conditions                                                       -0.007
# Weather_Conditions                                                      0.003
# Road_Surface_Conditions                                                -0.009
# Special_Conditions_at_Site                                             -0.009
# Carriageway_Hazards                                                     0.003
# Urban_or_Rural_Area                                                    -0.033
# Did_Police_Officer_Attend_Scene_of_Accident                             0.028
# Vehicle_Reference_df                                                   -0.038
# Casualty_Reference                                                     -0.029
# Casualty_Class                                                          0.048
# Sex_of_Casualty                                                        -0.013
# Age_of_Casualty                                                         0.004
# Age_Band_of_Casualty                                                    0.000
# Casualty_Severity                                                      -0.018
# Pedestrian_Location                                                     0.090
# Pedestrian_Movement                                                     0.148
# Car_Passenger                                                          -0.027
# Bus_or_Coach_Passenger                                                  0.007
# Pedestrian_Road_Maintenance_Worker                                      0.009
# Casualty_Type                                                          -0.030
# Casualty_Home_Area_Type                                                -0.012
# day_of_week                                                            -0.001
# hour_of_day                                                            -0.006
# night                                                                   0.007
# morning                                                                 0.003
# lunch                                                                  -0.001
# afternoon                                                              -0.001
# evening                                                                -0.004
#
#                                              Junction_Location  \
# Vehicle_Reference_df_res                                -0.078
# Vehicle_Type                                            -0.061
# Towing_and_Articulation                                 -0.031
# Vehicle_Manoeuvre                                        0.038
# Vehicle_Location-Restricted_Lane                        -0.014
# Junction_Location                                        1.000
# Skidding_and_Overturning                                -0.082
# Hit_Object_in_Carriageway                               -0.029
# Vehicle_Leaving_Carriageway                             -0.060
# Hit_Object_off_Carriageway                              -0.078
# 1st_Point_of_Impact                                      0.088
# Journey_Purpose_of_Driver                                0.019
# Sex_of_Driver                                           -0.034
# Age_of_Driver                                           -0.009
# Age_Band_of_Driver                                      -0.006
# Location_Easting_OSGR                                    0.141
# Location_Northing_OSGR                                  -0.085
# Longitude                                                0.140
# Latitude                                                -0.085
# Police_Force                                            -0.160
# Accident_Severity                                        0.068
# Number_of_Vehicles                                      -0.116
# Number_of_Casualties                                    -0.076
# Day_of_Week                                             -0.008
# Local_Authority_(District)                              -0.170
# 1st_Road_Class                                           0.067
# 1st_Road_Number                                          0.043
# Road_Type                                               -0.041
# Speed_limit                                             -0.256
# Junction_Detail                                          0.528
# 2nd_Road_Number                                          0.179
# Pedestrian_Crossing-Physical_Facilities                  0.154
# Light_Conditions                                        -0.024
# Weather_Conditions                                      -0.029
# Road_Surface_Conditions                                 -0.055
# Special_Conditions_at_Site                              -0.054
# Carriageway_Hazards                                     -0.053
# Urban_or_Rural_Area                                     -0.224
# Did_Police_Officer_Attend_Scene_of_Accident             -0.011
# Vehicle_Reference_df                                    -0.023
# Casualty_Reference                                      -0.060
# Casualty_Class                                          -0.083
# Sex_of_Casualty                                         -0.032
# Age_of_Casualty                                         -0.001
# Age_Band_of_Casualty                                     0.006
# Casualty_Severity                                        0.045
# Pedestrian_Location                                     -0.077
# Pedestrian_Movement                                     -0.067
# Car_Passenger                                           -0.029
# Bus_or_Coach_Passenger                                  -0.000
# Pedestrian_Road_Maintenance_Worker                      -0.006
# Casualty_Type                                           -0.066
# Casualty_Home_Area_Type                                 -0.086
# day_of_week                                             -0.006
# hour_of_day                                              0.015
# night                                                   -0.014
# morning                                                  0.014
# lunch                                                   -0.015
# afternoon                                               -0.020
# evening                                                  0.035
#
#                                              Skidding_and_Overturning  \
# Vehicle_Reference_df_res                                       -0.105
# Vehicle_Type                                                    0.007
# Towing_and_Articulation                                         0.036
# Vehicle_Manoeuvre                                               0.141
# Vehicle_Location-Restricted_Lane                               -0.007
# Junction_Location                                              -0.082
# Skidding_and_Overturning                                        1.000
# Hit_Object_in_Carriageway                                       0.143
# Vehicle_Leaving_Carriageway                                     0.247
# Hit_Object_off_Carriageway                                      0.279
# 1st_Point_of_Impact                                             0.002
# Journey_Purpose_of_Driver                                       0.002
# Sex_of_Driver                                                  -0.051
# Age_of_Driver                                                  -0.060
# Age_Band_of_Driver                                             -0.057
# Location_Easting_OSGR                                          -0.069
# Location_Northing_OSGR                                          0.048
# Longitude                                                      -0.069
# Latitude                                                        0.048
# Police_Force                                                    0.079
# Accident_Severity                                              -0.078
# Number_of_Vehicles                                             -0.110
# Number_of_Casualties                                            0.029
# Day_of_Week                                                    -0.009
# Local_Authority_(District)                                      0.083
# 1st_Road_Class                                                 -0.017
# 1st_Road_Number                                                 0.010
# Road_Type                                                       0.007
# Speed_limit                                                     0.160
# Junction_Detail                                                -0.089
# 2nd_Road_Number                                                -0.026
# Pedestrian_Crossing-Physical_Facilities                        -0.058
# Light_Conditions                                                0.077
# Weather_Conditions                                              0.029
# Road_Surface_Conditions                                         0.092
# Special_Conditions_at_Site                                      0.044
# Carriageway_Hazards                                             0.040
# Urban_or_Rural_Area                                             0.162
# Did_Police_Officer_Attend_Scene_of_Accident                    -0.073
# Vehicle_Reference_df                                           -0.086
# Casualty_Reference                                              0.020
# Casualty_Class                                                 -0.040
# Sex_of_Casualty                                                -0.027
# Age_of_Casualty                                                -0.019
# Age_Band_of_Casualty                                           -0.017
# Casualty_Severity                                              -0.060
# Pedestrian_Location                                            -0.055
# Pedestrian_Movement                                            -0.044
# Car_Passenger                                                   0.020
# Bus_or_Coach_Passenger                                         -0.021
# Pedestrian_Road_Maintenance_Worker                             -0.034
# Casualty_Type                                                   0.059
# Casualty_Home_Area_Type                                         0.076
# day_of_week                                                     0.018
# hour_of_day                                                    -0.025
# night                                                           0.072
# morning                                                        -0.003
# lunch                                                          -0.020
# afternoon                                                      -0.036
# evening                                                         0.029
#
#                                              Hit_Object_in_Carriageway  \
# Vehicle_Reference_df_res                                        -0.074
# Vehicle_Type                                                    -0.016
# Towing_and_Articulation                                         -0.002
# Vehicle_Manoeuvre                                                0.082
# Vehicle_Location-Restricted_Lane                                 0.040
# Junction_Location                                               -0.029
# Skidding_and_Overturning                                         0.143
# Hit_Object_in_Carriageway                                        1.000
# Vehicle_Leaving_Carriageway                                      0.199
# Hit_Object_off_Carriageway                                       0.193
# 1st_Point_of_Impact                                              0.006
# Journey_Purpose_of_Driver                                        0.020
# Sex_of_Driver                                                   -0.021
# Age_of_Driver                                                   -0.035
# Age_Band_of_Driver                                              -0.036
# Location_Easting_OSGR                                           -0.000
# Location_Northing_OSGR                                          -0.001
# Longitude                                                       -0.001
# Latitude                                                        -0.001
# Police_Force                                                    -0.007
# Accident_Severity                                               -0.035
# Number_of_Vehicles                                              -0.077
# Number_of_Casualties                                            -0.002
# Day_of_Week                                                     -0.008
# Local_Authority_(District)                                      -0.005
# 1st_Road_Class                                                   0.028
# 1st_Road_Number                                                  0.003
# Road_Type                                                       -0.002
# Speed_limit                                                     -0.010
# Junction_Detail                                                 -0.034
# 2nd_Road_Number                                                 -0.009
# Pedestrian_Crossing-Physical_Facilities                         -0.001
# Light_Conditions                                                 0.053
# Weather_Conditions                                               0.015
# Road_Surface_Conditions                                          0.023
# Special_Conditions_at_Site                                       0.006
# Carriageway_Hazards                                              0.114
# Urban_or_Rural_Area                                             -0.003
# Did_Police_Officer_Attend_Scene_of_Accident                     -0.035
# Vehicle_Reference_df                                            -0.078
# Casualty_Reference                                              -0.004
# Casualty_Class                                                  -0.005
# Sex_of_Casualty                                                 -0.018
# Age_of_Casualty                                                 -0.012
# Age_Band_of_Casualty                                            -0.010
# Casualty_Severity                                               -0.029
# Pedestrian_Location                                             -0.003
# Pedestrian_Movement                                              0.014
# Car_Passenger                                                    0.015
# Bus_or_Coach_Passenger                                          -0.009
# Pedestrian_Road_Maintenance_Worker                              -0.005
# Casualty_Type                                                    0.016
# Casualty_Home_Area_Type                                         -0.004
# day_of_week                                                      0.020
# hour_of_day                                                     -0.016
# night                                                            0.080
# morning                                                         -0.015
# lunch                                                           -0.018
# afternoon                                                       -0.036
# evening                                                          0.038
#
#                                              Vehicle_Leaving_Carriageway  \
# Vehicle_Reference_df_res                                          -0.106
# Vehicle_Type                                                       0.003
# Towing_and_Articulation                                            0.002
# Vehicle_Manoeuvre                                                  0.128
# Vehicle_Location-Restricted_Lane                                   0.015
# Junction_Location                                                 -0.060
# Skidding_and_Overturning                                           0.247
# Hit_Object_in_Carriageway                                          0.199
# Vehicle_Leaving_Carriageway                                        1.000
# Hit_Object_off_Carriageway                                         0.532
# 1st_Point_of_Impact                                                0.010
# Journey_Purpose_of_Driver                                          0.017
# Sex_of_Driver                                                     -0.040
# Age_of_Driver                                                     -0.034
# Age_Band_of_Driver                                                -0.032
# Location_Easting_OSGR                                             -0.049
# Location_Northing_OSGR                                             0.060
# Longitude                                                         -0.049
# Latitude                                                           0.060
# Police_Force                                                       0.068
# Accident_Severity                                                 -0.100
# Number_of_Vehicles                                                -0.121
# Number_of_Casualties                                               0.041
# Day_of_Week                                                       -0.011
# Local_Authority_(District)                                         0.070
# 1st_Road_Class                                                    -0.004
# 1st_Road_Number                                                    0.013
# Road_Type                                                          0.029
# Speed_limit                                                        0.158
# Junction_Detail                                                   -0.063
# 2nd_Road_Number                                                   -0.023
# Pedestrian_Crossing-Physical_Facilities                           -0.062
# Light_Conditions                                                   0.084
# Weather_Conditions                                                 0.021
# Road_Surface_Conditions                                            0.081
# Special_Conditions_at_Site                                         0.021
# Carriageway_Hazards                                                0.033
# Urban_or_Rural_Area                                                0.166
# Did_Police_Officer_Attend_Scene_of_Accident                       -0.088
# Vehicle_Reference_df                                              -0.090
# Casualty_Reference                                                 0.028
# Casualty_Class                                                    -0.024
# Sex_of_Casualty                                                   -0.018
# Age_of_Casualty                                                   -0.006
# Age_Band_of_Casualty                                              -0.006
# Casualty_Severity                                                 -0.069
# Pedestrian_Location                                               -0.047
# Pedestrian_Movement                                               -0.028
# Car_Passenger                                                      0.038
# Bus_or_Coach_Passenger                                            -0.021
# Pedestrian_Road_Maintenance_Worker                                -0.031
# Casualty_Type                                                      0.062
# Casualty_Home_Area_Type                                            0.080
# day_of_week                                                        0.015
# hour_of_day                                                       -0.019
# night                                                              0.081
# morning                                                           -0.014
# lunch                                                             -0.020
# afternoon                                                         -0.037
# evening                                                            0.039
#
#                                              Hit_Object_off_Carriageway  ...  \
# Vehicle_Reference_df_res                                         -0.110  ...
# Vehicle_Type                                                      0.003  ...
# Towing_and_Articulation                                           0.002  ...
# Vehicle_Manoeuvre                                                 0.132  ...
# Vehicle_Location-Restricted_Lane                                  0.013  ...
# Junction_Location                                                -0.078  ...
# Skidding_and_Overturning                                          0.279  ...
# Hit_Object_in_Carriageway                                         0.193  ...
# Vehicle_Leaving_Carriageway                                       0.532  ...
# Hit_Object_off_Carriageway                                        1.000  ...
# 1st_Point_of_Impact                                               0.005  ...
# Journey_Purpose_of_Driver                                         0.022  ...
# Sex_of_Driver                                                    -0.032  ...
# Age_of_Driver                                                    -0.039  ...
# Age_Band_of_Driver                                               -0.037  ...
# Location_Easting_OSGR                                            -0.068  ...
# Location_Northing_OSGR                                            0.062  ...
# Longitude                                                        -0.068  ...
# Latitude                                                          0.062  ...
# Police_Force                                                      0.071  ...
# Accident_Severity                                                -0.078  ...
# Number_of_Vehicles                                               -0.155  ...
# Number_of_Casualties                                              0.022  ...
# Day_of_Week                                                      -0.009  ...
# Local_Authority_(District)                                        0.074  ...
# 1st_Road_Class                                                   -0.005  ...
# 1st_Road_Number                                                   0.010  ...
# Road_Type                                                         0.018  ...
# Speed_limit                                                       0.156  ...
# Junction_Detail                                                  -0.077  ...
# 2nd_Road_Number                                                  -0.031  ...
# Pedestrian_Crossing-Physical_Facilities                          -0.064  ...
# Light_Conditions                                                  0.095  ...
# Weather_Conditions                                                0.028  ...
# Road_Surface_Conditions                                           0.092  ...
# Special_Conditions_at_Site                                        0.026  ...
# Carriageway_Hazards                                               0.037  ...
# Urban_or_Rural_Area                                               0.162  ...
# Did_Police_Officer_Attend_Scene_of_Accident                      -0.086  ...
# Vehicle_Reference_df                                             -0.112  ...
# Casualty_Reference                                                0.014  ...
# Casualty_Class                                                   -0.023  ...
# Sex_of_Casualty                                                  -0.015  ...
# Age_of_Casualty                                                  -0.012  ...
# Age_Band_of_Casualty                                             -0.013  ...
# Casualty_Severity                                                -0.058  ...
# Pedestrian_Location                                              -0.045  ...
# Pedestrian_Movement                                              -0.027  ...
# Car_Passenger                                                     0.039  ...
# Bus_or_Coach_Passenger                                           -0.019  ...
# Pedestrian_Road_Maintenance_Worker                               -0.031  ...
# Casualty_Type                                                     0.061  ...
# Casualty_Home_Area_Type                                           0.078  ...
# day_of_week                                                       0.019  ...
# hour_of_day                                                      -0.024  ...
# night                                                             0.094  ...
# morning                                                          -0.015  ...
# lunch                                                            -0.021  ...
# afternoon                                                        -0.045  ...
# evening                                                           0.045  ...
#
#                                              Pedestrian_Road_Maintenance_Worker  \
# Vehicle_Reference_df_res                                                 -0.101
# Vehicle_Type                                                             -0.002
# Towing_and_Articulation                                                  -0.011
# Vehicle_Manoeuvre                                                         0.026
# Vehicle_Location-Restricted_Lane                                          0.009
# Junction_Location                                                        -0.006
# Skidding_and_Overturning                                                 -0.034
# Hit_Object_in_Carriageway                                                -0.005
# Vehicle_Leaving_Carriageway                                              -0.031
# Hit_Object_off_Carriageway                                               -0.031
# 1st_Point_of_Impact                                                       0.009
# Journey_Purpose_of_Driver                                                 0.001
# Sex_of_Driver                                                             0.008
# Age_of_Driver                                                             0.005
# Age_Band_of_Driver                                                       -0.003
# Location_Easting_OSGR                                                     0.135
# Location_Northing_OSGR                                                   -0.113
# Longitude                                                                 0.133
# Latitude                                                                 -0.113
# Police_Force                                                             -0.138
# Accident_Severity                                                         0.003
# Number_of_Vehicles                                                       -0.172
# Number_of_Casualties                                                     -0.077
# Day_of_Week                                                               0.003
# Local_Authority_(District)                                               -0.155
# 1st_Road_Class                                                            0.009
# 1st_Road_Number                                                          -0.034
# Road_Type                                                                 0.041
# Speed_limit                                                              -0.093
# Junction_Detail                                                           0.016
# 2nd_Road_Number                                                          -0.024
# Pedestrian_Crossing-Physical_Facilities                                   0.056
# Light_Conditions                                                          0.000
# Weather_Conditions                                                       -0.013
# Road_Surface_Conditions                                                  -0.038
# Special_Conditions_at_Site                                               -0.011
# Carriageway_Hazards                                                      -0.001
# Urban_or_Rural_Area                                                      -0.103
# Did_Police_Officer_Attend_Scene_of_Accident                              -0.004
# Vehicle_Reference_df                                                     -0.117
# Casualty_Reference                                                       -0.056
# Casualty_Class                                                            0.361
# Sex_of_Casualty                                                           0.014
# Age_of_Casualty                                                          -0.016
# Age_Band_of_Casualty                                                     -0.023
# Casualty_Severity                                                        -0.013
# ...
# Location_Northing_OSGR                                         0.068
# Longitude                                                     -0.102
# Latitude                                                       0.067
# Police_Force                                                   0.189
# Accident_Severity                                             -0.065
# Number_of_Vehicles                                             0.016
# Number_of_Casualties                                           0.027
# Day_of_Week                                                    0.002
# Local_Authority_(District)                                     0.197
# 1st_Road_Class                                                -0.037
# 1st_Road_Number                                                0.012
# Road_Type                                                      0.054
# Speed_limit                                                    0.228
# Junction_Detail                                               -0.057
# 2nd_Road_Number                                               -0.014
# Pedestrian_Crossing-Physical_Facilities                       -0.100
# Light_Conditions                                              -0.001
# Weather_Conditions                                             0.015
# Road_Surface_Conditions                                        0.063
# Special_Conditions_at_Site                                     0.026
# Carriageway_Hazards                                            0.023
# Urban_or_Rural_Area                                            0.337
# Did_Police_Officer_Attend_Scene_of_Accident                   -0.042
# Vehicle_Reference_df                                           0.016
# Casualty_Reference                                             0.013
# Casualty_Class                                                -0.065
# Sex_of_Casualty                                                0.034
# Age_of_Casualty                                                0.074
# Age_Band_of_Casualty                                           0.065
# Casualty_Severity                                             -0.043
# Pedestrian_Location                                           -0.041
# Pedestrian_Movement                                           -0.030
# Car_Passenger                                                 -0.021
# Bus_or_Coach_Passenger                                        -0.031
# Pedestrian_Road_Maintenance_Worker                            -0.055
# Casualty_Type                                                  0.057
# Casualty_Home_Area_Type                                        1.000
# day_of_week                                                   -0.008
# hour_of_day                                                   -0.016
# night                                                         -0.030
# morning                                                        0.024
# lunch                                                          0.013
# afternoon                                                      0.012
# evening                                                       -0.040
#
#                                              day_of_week  hour_of_day  night  \
# Vehicle_Reference_df_res                          -0.003       -0.002 -0.031
# Vehicle_Type                                      -0.012       -0.035  0.007
# Towing_and_Articulation                           -0.010       -0.020  0.005
# Vehicle_Manoeuvre                                  0.014       -0.006  0.047
# Vehicle_Location-Restricted_Lane                  -0.001       -0.006  0.007
# Junction_Location                                 -0.006        0.015 -0.014
# Skidding_and_Overturning                           0.018       -0.025  0.072
# Hit_Object_in_Carriageway                          0.020       -0.016  0.080
# Vehicle_Leaving_Carriageway                        0.015       -0.019  0.081
# Hit_Object_off_Carriageway                         0.019       -0.024  0.094
# 1st_Point_of_Impact                               -0.006        0.001 -0.008
# Journey_Purpose_of_Driver                          0.078        0.157 -0.019
# Sex_of_Driver                                     -0.007        0.002 -0.023
# Age_of_Driver                                     -0.014       -0.039 -0.072
# Age_Band_of_Driver                                -0.015       -0.043 -0.077
# Location_Easting_OSGR                             -0.004       -0.004  0.008
# Location_Northing_OSGR                             0.007        0.005 -0.013
# Longitude                                         -0.004       -0.004  0.008
# Latitude                                           0.007        0.005 -0.013
# Police_Force                                      -0.007       -0.012 -0.020
# Accident_Severity                                 -0.024        0.007 -0.056
# Number_of_Vehicles                                -0.005       -0.003 -0.054
# Number_of_Casualties                               0.033        0.030  0.016
# Day_of_Week                                        0.231        0.035 -0.021
# Local_Authority_(District)                        -0.008       -0.012 -0.021
# 1st_Road_Class                                     0.001        0.031 -0.008
# 1st_Road_Number                                   -0.004       -0.001 -0.002
# Road_Type                                          0.003        0.015 -0.010
# Speed_limit                                        0.001       -0.041 -0.010
# Junction_Detail                                   -0.000        0.020 -0.026
# 2nd_Road_Number                                   -0.005        0.002 -0.000
# Pedestrian_Crossing-Physical_Facilities            0.005        0.011  0.020
# Light_Conditions                                   0.031        0.222  0.321
# Weather_Conditions                                -0.005        0.000  0.026
# Road_Surface_Conditions                           -0.021       -0.045  0.040
# Special_Conditions_at_Site                        -0.003       -0.014  0.007
# Carriageway_Hazards                                0.014       -0.011  0.035
# Urban_or_Rural_Area                               -0.001       -0.040 -0.020
# Did_Police_Officer_Attend_Scene_of_Accident       -0.007        0.006 -0.034
# Vehicle_Reference_df                              -0.010        0.007 -0.076
# Casualty_Reference                                 0.023        0.023  0.010
# Casualty_Class                                     0.026        0.032  0.034
# Sex_of_Casualty                                   -0.004        0.013 -0.073
# Age_of_Casualty                                   -0.014       -0.047 -0.065
# Age_Band_of_Casualty                              -0.014       -0.051 -0.053
# Casualty_Severity                                 -0.015        0.009 -0.049
# Pedestrian_Location                               -0.003       -0.001  0.020
# Pedestrian_Movement                               -0.000       -0.004  0.021
# Car_Passenger                                      0.047        0.041  0.051
# Bus_or_Coach_Passenger                            -0.004       -0.009 -0.018
# Pedestrian_Road_Maintenance_Worker                -0.006        0.002  0.004
# Casualty_Type                                      0.004       -0.019  0.016
# Casualty_Home_Area_Type                           -0.008       -0.016 -0.030
# day_of_week                                        1.000       -0.002  0.070
# hour_of_day                                       -0.002        1.000 -0.523
# night                                              0.070       -0.523  1.000
# morning                                           -0.066       -0.581 -0.119
# lunch                                              0.039       -0.152 -0.104
# afternoon                                         -0.021        0.387 -0.181
# evening                                            0.020        0.600 -0.099
#
#                                              morning  lunch  afternoon  \
# Vehicle_Reference_df_res                       0.008  0.010      0.023
# Vehicle_Type                                   0.018  0.022     -0.012
# Towing_and_Articulation                        0.010  0.015     -0.011
# Vehicle_Manoeuvre                             -0.000 -0.032     -0.025
# Vehicle_Location-Restricted_Lane               0.003 -0.001     -0.001
# Junction_Location                              0.014 -0.015     -0.020
# Skidding_and_Overturning                      -0.003 -0.020     -0.036
# Hit_Object_in_Carriageway                     -0.015 -0.018     -0.036
# Vehicle_Leaving_Carriageway                   -0.014 -0.020     -0.037
# Hit_Object_off_Carriageway                    -0.015 -0.021     -0.045
# 1st_Point_of_Impact                            0.010 -0.006     -0.004
# Journey_Purpose_of_Driver                     -0.187  0.056      0.048
# Sex_of_Driver                                  0.008  0.005      0.014
# Age_of_Driver                                  0.021  0.089      0.025
# Age_Band_of_Driver                             0.028  0.088      0.026
# Location_Easting_OSGR                          0.022 -0.020     -0.026
# Location_Northing_OSGR                        -0.021  0.024      0.024
# Longitude                                      0.022 -0.019     -0.026
# Latitude                                      -0.021  0.024      0.024
# Police_Force                                   0.008  0.022      0.011
# Accident_Severity                              0.027  0.005      0.017
# Number_of_Vehicles                             0.013  0.017      0.040
# Number_of_Casualties                          -0.069  0.024      0.023
# Day_of_Week                                   -0.019  0.010     -0.006
# Local_Authority_(District)                     0.007  0.024      0.013
# 1st_Road_Class                                -0.022 -0.005      0.004
# 1st_Road_Number                                0.003 -0.000     -0.000
# Road_Type                                     -0.015  0.006      0.010
# Speed_limit                                    0.036  0.008      0.013
# Junction_Detail                               -0.003  0.005      0.000
# 2nd_Road_Number                               -0.000  0.002     -0.003
# Pedestrian_Crossing-Physical_Facilities       -0.015 -0.004     -0.021
# Light_Conditions                              -0.223 -0.260     -0.095
# Weather_Conditions                             0.007 -0.031     -0.011
# Road_Surface_Conditions                        0.070 -0.053     -0.052
# Special_Conditions_at_Site                     0.008  0.011     -0.014
# Carriageway_Hazards                           -0.006 -0.009     -0.008
# Urban_or_Rural_Area                            0.035  0.017      0.014
# Did_Police_Officer_Attend_Scene_of_Accident    0.011 -0.003      0.025
# Vehicle_Reference_df                           0.023  0.016      0.039
# Casualty_Reference                            -0.052  0.018      0.019
# Casualty_Class                                -0.077  0.015      0.024
# Sex_of_Casualty                                0.001  0.046      0.030
# Age_of_Casualty                                0.032  0.098     -0.007
# Age_Band_of_Casualty                           0.039  0.088     -0.018
# Casualty_Severity                              0.017  0.011      0.015
# Pedestrian_Location                           -0.016 -0.006      0.010
# Pedestrian_Movement                           -0.013 -0.002      0.004
# Car_Passenger                                 -0.093  0.016      0.012
# Bus_or_Coach_Passenger                        -0.002  0.036      0.005
# Pedestrian_Road_Maintenance_Worker            -0.001 -0.009      0.001
# Casualty_Type                                 -0.006  0.025     -0.011
# Casualty_Home_Area_Type                        0.024  0.013      0.012
# day_of_week                                   -0.066  0.039     -0.021
# hour_of_day                                   -0.581 -0.152      0.387
# night                                         -0.119 -0.104     -0.181
# morning                                        1.000 -0.246     -0.428
# lunch                                         -0.246  1.000     -0.372
# afternoon                                     -0.428 -0.372      1.000
# evening                                       -0.234 -0.203     -0.354
#
#                                              evening
# Vehicle_Reference_df_res                      -0.032
# Vehicle_Type                                  -0.030
# Towing_and_Articulation                       -0.015
# Vehicle_Manoeuvre                              0.038
# Vehicle_Location-Restricted_Lane              -0.004
# Junction_Location                              0.035
# Skidding_and_Overturning                       0.029
# Hit_Object_in_Carriageway                      0.038
# Vehicle_Leaving_Carriageway                    0.039
# Hit_Object_off_Carriageway                     0.045
# 1st_Point_of_Impact                            0.005
# Journey_Purpose_of_Driver                      0.098
# Sex_of_Driver                                 -0.019
# Age_of_Driver                                 -0.107
# Age_Band_of_Driver                            -0.112
# Location_Easting_OSGR                          0.026
# Location_Northing_OSGR                        -0.027
# Longitude                                      0.025
# Latitude                                      -0.027
# Police_Force                                  -0.036
# Accident_Severity                             -0.026
# Number_of_Vehicles                            -0.055
# Number_of_Casualties                           0.013
# Day_of_Week                                    0.031
# Local_Authority_(District)                    -0.038
# 1st_Road_Class                                 0.028
# 1st_Road_Number                               -0.001
# Road_Type                                      0.003
# Speed_limit                                   -0.060
# Junction_Detail                                0.013
# 2nd_Road_Number                                0.003
# Pedestrian_Crossing-Physical_Facilities        0.037
# Light_Conditions                               0.460
# Weather_Conditions                             0.024
# Road_Surface_Conditions                        0.022
# Special_Conditions_at_Site                    -0.006
# Carriageway_Hazards                            0.007
# Urban_or_Rural_Area                           -0.065
# Did_Police_Officer_Attend_Scene_of_Accident   -0.023
# Vehicle_Reference_df                          -0.050
# Casualty_Reference                             0.009
# Casualty_Class                                 0.020
# Sex_of_Casualty                               -0.046
# Age_of_Casualty                               -0.091
# Age_Band_of_Casualty                          -0.081
# Casualty_Severity                             -0.021
# Pedestrian_Location                           -0.001
# Pedestrian_Movement                           -0.001
# Car_Passenger                                  0.043
# Bus_or_Coach_Passenger                        -0.031
# Pedestrian_Road_Maintenance_Worker             0.007
# Casualty_Type                                 -0.014
# Casualty_Home_Area_Type                       -0.040
# day_of_week                                    0.020
# hour_of_day                                    0.600
# night                                         -0.099
# morning                                       -0.234
# lunch                                         -0.203
# afternoon                                     -0.354
# evening                                        1.000
#
# [60 rows x 60 columns]

# %%
# Create labels for the correlation matrix
labels = np.where(np.abs(df_corr)>0.75,'S',
                  np.where(np.abs(df_corr)>0.5,'M',
                           np.where(np.abs(df_corr)>0.25,'W','')))

# Plot correlation matrix
plt.figure(figsize=(15, 15))
sns.heatmap(df_corr, mask=np.eye(len(df_corr)), square=True,
            center=0, annot=labels, fmt='', linewidths=.5,
            cmap="vlag", cbar_kws={"shrink": 0.8});

# %%
sns.clustermap(df_corr, mask=np.eye(len(df_corr)), center=0, cmap="vlag",
               cbar_pos=(-0.08, 0.4, 0.04, 0.4), dendrogram_ratio=(0, 0.1),
               figsize=(15, 15));
